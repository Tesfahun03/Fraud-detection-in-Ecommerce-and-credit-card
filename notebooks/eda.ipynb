# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os, sys

# %%
sys.path.append(os.path.abspath('..'))

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from src.eda import EdaAnalysis, EdaPlot

# %%
df1 = pd.read_csv('../data/Fraud_Data.csv')
df2 = pd.read_csv('../data/IpAddress_to_Country.csv')
df1['ip_address'] = df1['ip_address'].astype(int)
df1['signup_time'] = pd.to_datetime(df1['signup_time'], errors = 'coerce')
df1['purchase_time'] = pd.to_datetime(df1['purchase_time'], errors = 'coerce')

# %%
eda = EdaAnalysis(df1)

# %%
eda.get_categorical_distribution()
# Out:
# {'device_id': device_id
#  CQTUVBYIWWWBC    20
#  NGQCKIADMZORL    20
#  ZUSVMDEZRBDTX    20
#  ITUMJCKWEYNDD    20
#  EQYVNEGOFLAWK    20
#                   ..
#  JUWCOHMHRBDCL     1
#  YIIEFBZUGEXNR     1
#  BCDMJZBWLCVVJ     1
#  VVZIVFUBISCEV     1
#  REPNWECRCGXIS     1
#  Name: count, Length: 137956, dtype: int64,
#  'source': source
#  SEO       60615
#  Ads       59881
#  Direct    30616
#  Name: count, dtype: int64,
#  'browser': browser
#  Chrome     61432
#  IE         36727
#  Safari     24667
#  FireFox    24610
#  Opera       3676
#  Name: count, dtype: int64,
#  'sex': sex
#  M    88293
#  F    62819
#  Name: count, dtype: int64}

# %%
eda.get_correlation()
# Out:
#                  user_id  purchase_value       age  ip_address     class
# user_id         1.000000        0.002617  0.000611   -0.003144  0.001945
# purchase_value  0.002617        1.000000  0.002370   -0.000328  0.001011
# age             0.000611        0.002370  1.000000    0.001140  0.006624
# ip_address     -0.003144       -0.000328  0.001140    1.000000 -0.005208
# class           0.001945        0.001011  0.006624   -0.005208  1.000000

# %%
eda.get_descriptive_statistics()
# Out:
#              user_id                    signup_time  \
# count  151112.000000                         151112
# mean   200171.040970  2015-04-20 00:56:09.511329280
# min         2.000000            2015-01-01 00:00:42
# 25%    100642.500000     2015-02-18 09:52:48.500000
# 50%    199958.000000            2015-04-19 04:41:30
# 75%    300054.000000  2015-06-18 14:47:22.750000128
# max    400000.000000            2015-08-18 04:40:29
# std    115369.285024                            NaN
#
#                        purchase_time  purchase_value            age  \
# count                         151112   151112.000000  151112.000000
# mean   2015-06-16 02:56:38.759952896       36.935372      33.140704
# min              2015-01-01 00:00:44        9.000000      18.000000
# 25%       2015-04-18 14:41:25.500000       22.000000      27.000000
# 50%       2015-06-18 13:46:17.500000       35.000000      33.000000
# 75%       2015-08-17 18:48:31.500000       49.000000      39.000000
# ...

# %%
eda.get_missing_values()
# Out:
# Series([], dtype: int64)

# %%
plot = EdaPlot(df1)

# %%
plot.plot_categorical_distribution('browser')

# %%
plot.plot_categorical_distribution('source')

# %%
plot.plot_categorical_distribution('class')

# %%
plot.plot_categorical_distribution('sex')

# %%
plot.plot_numerical_distribution('purchase_value')

# %%
plot.plot_numerical_distribution('age')
